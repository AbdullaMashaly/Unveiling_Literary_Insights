# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
#Load CSV data into Pandas DataFrame
csv_file_path = 'Resources/panda_df/books_cleaned_sample3.csv'
df = pd.read_csv(csv_file_path)

# %%
#Scatter plot for Average Rating vs. Author Average Rating
plt.scatter(df['average_rating'], df['author_average_rating'], marker="o", facecolors="red", edgecolors="black", alpha=0.75)
plt.title("Average Rating vs. Author Average Rating")
plt.xlabel("Average Rating")
plt.ylabel("Author Average Rating")
plt.show()

# %%
#Histogram for Number of Pages
plt.hist(df['num_pages'], bins=50, color='skyblue', edgecolor='black')
plt.title("Distribution of Number of Pages")
plt.xlabel("Number of Pages")
plt.ylabel("Frequency")

plt.show()

# %%
#Log Transformation (to help visualize the distribution more effectively)
#Add a small constant to avoid taking the logarithm of zero or negative values
df['log_num_pages'] = np.log(df['num_pages'] + 1)

#Plot the histogram
plt.hist(df['log_num_pages'], bins=50, color='skyblue', edgecolor='black')
plt.title("Distribution of Log (Number of Pages)")
plt.xlabel("Log (Number of Pages)")
plt.ylabel("Frequency")

plt.show()

# %%
#Create custom bins with intervals of 100 pages each
df['log_num_pages'] = np.log1p(df['num_pages'])

#Define custom bin edges
bin_width = 0.1
custom_bins = np.arange(0, df['log_num_pages'].max() + bin_width, bin_width)

#Plot the histogram with custom bins
plt.hist(df['num_pages'], bins=custom_bins, color='skyblue', edgecolor='black')
plt.title("Distribution of Number of Pages")
plt.xlabel("Number of Pages")
plt.ylabel("Frequency")

# Set custom labels for a subset of bins on the x-axis
visible_labels = 10  # Adjust the number of visible labels
label_indices = np.linspace(0, len(custom_bins) - 1, visible_labels, dtype=int)
plt.xticks(custom_bins[label_indices], [f"{round(np.exp(x)-1)}-{round(np.exp(x+bin_width)-1)}" for x in custom_bins[label_indices]], rotation=45)

plt.show()

# %%
# Count the number of blanks (missing values) in the 'num_pages' column
blank_count = df['num_pages'].isnull().sum()

# Count the number of zeros in the 'num_pages' column
zero_count = (df['num_pages'] == 0).sum()

print(f"Number of blanks (missing values): {blank_count}")
print(f"Number of zeros: {zero_count}")
# Out:
# Number of blanks (missing values): 0
# Number of zeros: 336

# %%
# Bar chart for Format
format_counts = df['format'].value_counts()
plt.bar(format_counts.index, format_counts.values, color='lightcoral')
plt.title("Distribution of Book Formats")
plt.xlabel("Book Format")
plt.ylabel("Count")
plt.xticks(rotation=45, ha='right')

plt.show()

# %%
#Line chart for Publication Year
year_counts = df['publication_year'].value_counts().sort_index()
plt.plot(year_counts.index, year_counts.values, marker='o', color='green')
plt.title("Number of Books Published Each Year")
plt.xlabel("Publication Year")
plt.ylabel("Number of Books")

plt.show()

# %%
#Create new line chart for Publication Year filtering out values after 2023
filtered_df = df[df['publication_year'] <= 2023]

#Calculate the number of books published each year in the filtered DataFrame
year_counts = filtered_df['publication_year'].value_counts().sort_index()

#Plot the line chart
plt.plot(year_counts.index, year_counts.values, marker='o', color='green')
plt.title("Number of Books Published Each Year")
plt.xlabel("Publication Year")
plt.ylabel("Number of Books")

plt.show()

# %%
#Find the value counts of each publication year
year_value_counts = df['publication_year'].value_counts().sort_index()

#Print or display the value counts
print("Value Counts of Publication Year:")
print(year_value_counts)
# Out:
# Value Counts of Publication Year:
# 1912       2
# 1913       2
# 1914       1
# 1915       1
# 1916       1
#         ...
# 2015    4478
# 2016    3800
# 2017    1930
# 2018      55
# 2020       1
# Name: publication_year, Length: 96, dtype: int64

# %%
# Pie chart for Series Binary
series_counts = df['series_binary'].value_counts()
plt.pie(series_counts, labels=['Not in Series', 'In Series'], autopct='%1.1f%%', colors=['gold', 'lightgreen'])
plt.title('Distribution of Series and Non-Series Books')
plt.show()

# %%
#Create a scatter plot of average_rating vs. rating_count
plt.figure(figsize=(10, 6))
sns.scatterplot(x='average_rating', y='ratings_count', data=df, alpha=0.5)
plt.title("Average Rating vs. Rating Count")
plt.xlabel("Average Rating")
plt.ylabel("Rating Count")

plt.show()

# %%
#Create a scatter plot of average_rating vs. text_reviews_count
plt.figure(figsize=(10, 6))
sns.scatterplot(x='average_rating', y='text_reviews_count', data=df, alpha=0.5)
plt.title("Average Rating vs. Text Reviews Count")
plt.xlabel("Average Rating")
plt.ylabel("Text Reviews Count")

plt.show()

# %%
#Make the y-axis logarithmic
plt.figure(figsize=(10, 6))
sns.scatterplot(x='average_rating', y='text_reviews_count', data=df, alpha=0.5)
plt.yscale('log')
plt.title("Average Rating vs. Text Reviews Count")
plt.xlabel("Average Rating")
plt.ylabel("Text Reviews Count")

plt.show()

# %%
#Create a scatter plot of average_rating vs. to_read_count
plt.figure(figsize=(10, 6))
sns.scatterplot(x='average_rating', y='to_read_count', data=df, alpha=0.5)
plt.title("Average Rating vs. To Read Count")
plt.xlabel("Average Rating")
plt.ylabel("To Read Count")

plt.show()

# %%
#Make the y-axis logarithmic
plt.figure(figsize=(10, 6))
sns.scatterplot(x='average_rating', y='to_read_count', data=df, alpha=0.5)
plt.yscale('log')
plt.title("Average Rating vs. To Read Count")
plt.xlabel("Average Rating")
plt.ylabel("To Read Count")

plt.show()

# %%
#Create a scatter plot of average_rating vs. series_binary
plt.figure(figsize=(10, 6))
sns.scatterplot(x='average_rating', y='series_binary', data=df, alpha=0.5)
plt.title("Average Rating vs. In a Series")
plt.xlabel("Average Rating")
plt.ylabel("In a Series")

plt.show()

# %%
#Create a scatter plot of average_rating vs. author_average_rating
plt.figure(figsize=(10, 6))
sns.scatterplot(x='average_rating', y='author_average_rating', data=df, alpha=0.5)
plt.title("Average Rating vs. Author Average Rating")
plt.xlabel("Average Rating")
plt.ylabel("Author Average Rating")

plt.show()

# %%
#Create a scatter plot of average_rating vs. format
plt.figure(figsize=(10, 6))
sns.scatterplot(x='average_rating', y='format', data=df, alpha=0.5)
plt.title("Average Rating vs. Book Format")
plt.xlabel("Average Rating")
plt.ylabel("Book Format")

plt.show()

# %%
#Create a scatter plot of average_rating vs. num_pages
plt.figure(figsize=(10, 6))
sns.scatterplot(x='average_rating', y='num_pages', data=df, alpha=0.5)
plt.title("Average Rating vs. Number of Pages")
plt.xlabel("Average Rating")
plt.ylabel("Number of Pages")

plt.show()

# %%
#Create a scatter plot of average_rating vs. publication_year
plt.figure(figsize=(10, 6))
sns.scatterplot(x='average_rating', y='publication_year', data=df, alpha=0.5)
plt.title("Average Rating vs. Publication Year")
plt.xlabel("Average Rating")
plt.ylabel("Publication Year")

plt.show()

# %%
#Find the column headers of the different genres
column_headers = df.columns
genres = column_headers[13:23]
print(genres)
# Out:
# Index(['history, historical fiction, biography', 'mystery, thriller, crime',
#        'non-fiction', 'poetry', 'romance', 'young-adult', 'log_num_pages'],
#       dtype='object')

# %%
#Create a heatmap to represent the correlation between the avearge rating and binary genres
#Select the rlevant columns
selected_columns= ['history, historical fiction, biography', 'mystery, thriller, crime',
       'non-fiction', 'poetry', 'romance', 'young-adult', 'average_rating']

#Create a subset of the DataFrame with selected columns
subset_df = df[selected_columns]

#Calculate the correlation matrix
correlation_matrix = subset_df.corr()

#Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix for Average Rating and Genres")
plt.xlabel("Genres")
plt.ylabel("Average Rating")

plt.show()

# %%
#Create a heatmap to represent the correlation between the avearge rating and all of the other features
#Extract the non-numeric column for encoding
non_numeric_column = df['format']

#Use LabelEncoder to encode the non-numeric column
label_encoder = LabelEncoder()
encoded_format = label_encoder.fit_transform(non_numeric_column)

#Replace the non-numeric column with the encoded column
df['format'] = encoded_format

#Select the numeric columns for correlation analysis
numeric_columns = df.select_dtypes(include=['int64', 'float64'])

#Calculate the correlation matrix
correlation_matrix = numeric_columns.corr()

#Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.xlabel("Features")
plt.ylabel("Features")

plt.show()
